% %% [markdown]
% # Advanced ML Topics HW 2

% %% [markdown]
% ## Part 3: Subsets of similar opcodes

% %%
!cat exmp/*.txt | sort | uniq > all_opcodes.txt

% %%
% Out:
% all_opcodes =
% {
%   [1,1] = 1
%   [2,1] = 10
%   [3,1] = 11
%   [4,1] = 12
%   [5,1] = 13
%   [6,1] = 14
%   [7,1] = 15
%   [8,1] = 18
%   [9,1] = 2
%   [10,1] = 20
%   [11,1] = 23
%   [12,1] = 3
%   [13,1] = 4
%   [14,1] = 5
%   [15,1] = 6
%   [16,1] = 7
%   [17,1] = 7ve
%   [18,1] = 8
%   [19,1] = 8sb
%   [20,1] = 9
%   [21,1] = aaa
%   [22,1] = aad
%   [23,1] = aam
%   [24,1] = aas
%   [25,1] = adc
%   [26,1] = add
%   [27,1] = and
%   [28,1] = andnps
%   [29,1] = arpl
%   [30,1] = bound
%   [31,1] = bsr
%   [32,1] = bt
%   [33,1] = bts
%   [34,1] = call
%   [35,1] = cdq
%   [36,1] = clc
%   [37,1] = cld
%   [38,1] = cli
%   [39,1] = cmc
%   [40,1] = cmp
%   [41,1] = cmps
%   [42,1] = cmpsb
%   [43,1] = cmpsd
%   [44,1] = cmpxchg
%   [45,1] = cwde
%   [46,1] = daa
%   [47,1] = das
%   [48,1] = dec
%   [49,1] = div
%   [50,1] = enter
%   [51,1] = fabs
%   [52,1] = fadd
%   [53,1] = faddp
%   [54,1] = fbld
%   [55,1] = fchs
%   [56,1] = fcmovb
%   [57,1] = fcmovnbe
% ...
